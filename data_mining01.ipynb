# %% [markdown]
# # **1. 数据的基本统计描述-集中趋势**

# %%
import numpy as np
from sklearn.datasets import load_iris

# %%
iris_data = load_iris()

# %% [markdown]
# iris数据集的中文名是安德森鸢尾花卉数据集
# ![image.png](attachment:image.png)

# %%
iris_data.data
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
#        [5.2, 4.1, 1.5, 0.1],
#        [5.5, 4.2, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.2],
#        [5. , 3.2, 1.2, 0.2],
#        [5.5, 3.5, 1.3, 0.2],
#        [4.9, 3.6, 1.4, 0.1],
#        [4.4, 3. , 1.3, 0.2],
#        [5.1, 3.4, 1.5, 0.2],
#        [5. , 3.5, 1.3, 0.3],
#        [4.5, 2.3, 1.3, 0.3],
#        [4.4, 3.2, 1.3, 0.2],
#        [5. , 3.5, 1.6, 0.6],
#        [5.1, 3.8, 1.9, 0.4],
#        [4.8, 3. , 1.4, 0.3],
#        [5.1, 3.8, 1.6, 0.2],
#        [4.6, 3.2, 1.4, 0.2],
#        [5.3, 3.7, 1.5, 0.2],
#        [5. , 3.3, 1.4, 0.2],
#        [7. , 3.2, 4.7, 1.4],
#        [6.4, 3.2, 4.5, 1.5],
#        [6.9, 3.1, 4.9, 1.5],
#        [5.5, 2.3, 4. , 1.3],
#        [6.5, 2.8, 4.6, 1.5],
#        [5.7, 2.8, 4.5, 1.3],
#        [6.3, 3.3, 4.7, 1.6],
#        [4.9, 2.4, 3.3, 1. ],
#        [6.6, 2.9, 4.6, 1.3],
#        [5.2, 2.7, 3.9, 1.4],
#        [5. , 2. , 3.5, 1. ],
#        [5.9, 3. , 4.2, 1.5],
#        [6. , 2.2, 4. , 1. ],
#        [6.1, 2.9, 4.7, 1.4],
#        [5.6, 2.9, 3.6, 1.3],
#        [6.7, 3.1, 4.4, 1.4],
#        [5.6, 3. , 4.5, 1.5],
#        [5.8, 2.7, 4.1, 1. ],
#        [6.2, 2.2, 4.5, 1.5],
#        [5.6, 2.5, 3.9, 1.1],
#        [5.9, 3.2, 4.8, 1.8],
#        [6.1, 2.8, 4. , 1.3],
#        [6.3, 2.5, 4.9, 1.5],
#        [6.1, 2.8, 4.7, 1.2],
#        [6.4, 2.9, 4.3, 1.3],
#        [6.6, 3. , 4.4, 1.4],
#        [6.8, 2.8, 4.8, 1.4],
#        [6.7, 3. , 5. , 1.7],
#        [6. , 2.9, 4.5, 1.5],
#        [5.7, 2.6, 3.5, 1. ],
#        [5.5, 2.4, 3.8, 1.1],
#        [5.5, 2.4, 3.7, 1. ],
#        [5.8, 2.7, 3.9, 1.2],
#        [6. , 2.7, 5.1, 1.6],
#        [5.4, 3. , 4.5, 1.5],
#        [6. , 3.4, 4.5, 1.6],
#        [6.7, 3.1, 4.7, 1.5],
#        [6.3, 2.3, 4.4, 1.3],
#        [5.6, 3. , 4.1, 1.3],
#        [5.5, 2.5, 4. , 1.3],
#        [5.5, 2.6, 4.4, 1.2],
#        [6.1, 3. , 4.6, 1.4],
#        [5.8, 2.6, 4. , 1.2],
#        [5. , 2.3, 3.3, 1. ],
#        [5.6, 2.7, 4.2, 1.3],
#        [5.7, 3. , 4.2, 1.2],
#        [5.7, 2.9, 4.2, 1.3],
#        [6.2, 2.9, 4.3, 1.3],
#        [5.1, 2.5, 3. , 1.1],
#        [5.7, 2.8, 4.1, 1.3],
#        [6.3, 3.3, 6. , 2.5],
#        [5.8, 2.7, 5.1, 1.9],
#        [7.1, 3. , 5.9, 2.1],
#        [6.3, 2.9, 5.6, 1.8],
#        [6.5, 3. , 5.8, 2.2],
#        [7.6, 3. , 6.6, 2.1],
#        [4.9, 2.5, 4.5, 1.7],
#        [7.3, 2.9, 6.3, 1.8],
#        [6.7, 2.5, 5.8, 1.8],
#        [7.2, 3.6, 6.1, 2.5],
#        [6.5, 3.2, 5.1, 2. ],
#        [6.4, 2.7, 5.3, 1.9],
#        [6.8, 3. , 5.5, 2.1],
#        [5.7, 2.5, 5. , 2. ],
#        [5.8, 2.8, 5.1, 2.4],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.5, 3. , 5.5, 1.8],
#        [7.7, 3.8, 6.7, 2.2],
#        [7.7, 2.6, 6.9, 2.3],
#        [6. , 2.2, 5. , 1.5],
#        [6.9, 3.2, 5.7, 2.3],
#        [5.6, 2.8, 4.9, 2. ],
#        [7.7, 2.8, 6.7, 2. ],
#        [6.3, 2.7, 4.9, 1.8],
#        [6.7, 3.3, 5.7, 2.1],
#        [7.2, 3.2, 6. , 1.8],
#        [6.2, 2.8, 4.8, 1.8],
#        [6.1, 3. , 4.9, 1.8],
#        [6.4, 2.8, 5.6, 2.1],
#        [7.2, 3. , 5.8, 1.6],
#        [7.4, 2.8, 6.1, 1.9],
#        [7.9, 3.8, 6.4, 2. ],
#        [6.4, 2.8, 5.6, 2.2],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.1, 2.6, 5.6, 1.4],
#        [7.7, 3. , 6.1, 2.3],
#        [6.3, 3.4, 5.6, 2.4],
#        [6.4, 3.1, 5.5, 1.8],
#        [6. , 3. , 4.8, 1.8],
#        [6.9, 3.1, 5.4, 2.1],
#        [6.7, 3.1, 5.6, 2.4],
#        [6.9, 3.1, 5.1, 2.3],
#        [5.8, 2.7, 5.1, 1.9],
#        [6.8, 3.2, 5.9, 2.3],
#        [6.7, 3.3, 5.7, 2.5],
#        [6.7, 3. , 5.2, 2.3],
#        [6.3, 2.5, 5. , 1.9],
#        [6.5, 3. , 5.2, 2. ],
#        [6.2, 3.4, 5.4, 2.3],
#        [5.9, 3. , 5.1, 1.8]])

# %%
iris_data.data.shape  #矩阵行列数
# Out:
# (150, 4)

# %%
#获取第一条数据
iris_data.data[0,:]
# Out:
# array([5.1, 3.5, 1.4, 0.2])

# %%
# 获取第⼀个维度的所有取值，作为⼀维向量
iris_data.data[:,0]
# Out:
# array([5.1, 4.9, 4.7, 4.6, 5. , 5.4, 4.6, 5. , 4.4, 4.9, 5.4, 4.8, 4.8,
#        4.3, 5.8, 5.7, 5.4, 5.1, 5.7, 5.1, 5.4, 5.1, 4.6, 5.1, 4.8, 5. ,
#        5. , 5.2, 5.2, 4.7, 4.8, 5.4, 5.2, 5.5, 4.9, 5. , 5.5, 4.9, 4.4,
#        5.1, 5. , 4.5, 4.4, 5. , 5.1, 4.8, 5.1, 4.6, 5.3, 5. , 7. , 6.4,
#        6.9, 5.5, 6.5, 5.7, 6.3, 4.9, 6.6, 5.2, 5. , 5.9, 6. , 6.1, 5.6,
#        6.7, 5.6, 5.8, 6.2, 5.6, 5.9, 6.1, 6.3, 6.1, 6.4, 6.6, 6.8, 6.7,
#        6. , 5.7, 5.5, 5.5, 5.8, 6. , 5.4, 6. , 6.7, 6.3, 5.6, 5.5, 5.5,
#        6.1, 5.8, 5. , 5.6, 5.7, 5.7, 6.2, 5.1, 5.7, 6.3, 5.8, 7.1, 6.3,
#        6.5, 7.6, 4.9, 7.3, 6.7, 7.2, 6.5, 6.4, 6.8, 5.7, 5.8, 6.4, 6.5,
#        7.7, 7.7, 6. , 6.9, 5.6, 7.7, 6.3, 6.7, 7.2, 6.2, 6.1, 6.4, 7.2,
#        7.4, 7.9, 6.4, 6.3, 6.1, 7.7, 6.3, 6.4, 6. , 6.9, 6.7, 6.9, 5.8,
#        6.8, 6.7, 6.7, 6.3, 6.5, 6.2, 5.9])

# %%
# 获取第⼀个维度的所有取值，作为⼆维数组
iris_data.data[:,np.newaxis,0]
# Out:
# array([[5.1],
#        [4.9],
#        [4.7],
#        [4.6],
#        [5. ],
#        [5.4],
#        [4.6],
#        [5. ],
#        [4.4],
#        [4.9],
#        [5.4],
#        [4.8],
#        [4.8],
#        [4.3],
#        [5.8],
#        [5.7],
#        [5.4],
#        [5.1],
#        [5.7],
#        [5.1],
#        [5.4],
#        [5.1],
#        [4.6],
#        [5.1],
#        [4.8],
#        [5. ],
#        [5. ],
#        [5.2],
#        [5.2],
#        [4.7],
#        [4.8],
#        [5.4],
#        [5.2],
#        [5.5],
#        [4.9],
#        [5. ],
#        [5.5],
#        [4.9],
#        [4.4],
#        [5.1],
#        [5. ],
#        [4.5],
#        [4.4],
#        [5. ],
#        [5.1],
#        [4.8],
#        [5.1],
#        [4.6],
#        [5.3],
#        [5. ],
#        [7. ],
#        [6.4],
#        [6.9],
#        [5.5],
#        [6.5],
#        [5.7],
#        [6.3],
#        [4.9],
#        [6.6],
#        [5.2],
#        [5. ],
#        [5.9],
#        [6. ],
#        [6.1],
#        [5.6],
#        [6.7],
#        [5.6],
#        [5.8],
#        [6.2],
#        [5.6],
#        [5.9],
#        [6.1],
#        [6.3],
#        [6.1],
#        [6.4],
#        [6.6],
#        [6.8],
#        [6.7],
#        [6. ],
#        [5.7],
#        [5.5],
#        [5.5],
#        [5.8],
#        [6. ],
#        [5.4],
#        [6. ],
#        [6.7],
#        [6.3],
#        [5.6],
#        [5.5],
#        [5.5],
#        [6.1],
#        [5.8],
#        [5. ],
#        [5.6],
#        [5.7],
#        [5.7],
#        [6.2],
#        [5.1],
#        [5.7],
#        [6.3],
#        [5.8],
#        [7.1],
#        [6.3],
#        [6.5],
#        [7.6],
#        [4.9],
#        [7.3],
#        [6.7],
#        [7.2],
#        [6.5],
#        [6.4],
#        [6.8],
#        [5.7],
#        [5.8],
#        [6.4],
#        [6.5],
#        [7.7],
#        [7.7],
#        [6. ],
#        [6.9],
#        [5.6],
#        [7.7],
#        [6.3],
#        [6.7],
#        [7.2],
#        [6.2],
#        [6.1],
#        [6.4],
#        [7.2],
#        [7.4],
#        [7.9],
#        [6.4],
#        [6.3],
#        [6.1],
#        [7.7],
#        [6.3],
#        [6.4],
#        [6. ],
#        [6.9],
#        [6.7],
#        [6.9],
#        [5.8],
#        [6.8],
#        [6.7],
#        [6.7],
#        [6.3],
#        [6.5],
#        [6.2],
#        [5.9]])

# %% [markdown]
# ## **1.1均值**

# %%
# 计算每个属性的均值
np.mean(iris_data.data, axis=0)
# Out:
# array([5.84333333, 3.05733333, 3.758     , 1.19933333])

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## **1.2中位数**

# %%
# 计算每个属性的中位数
np.median(iris_data.data, axis=0)
# Out:
# array([5.8 , 3.  , 4.35, 1.3 ])

# %% [markdown]
# ## **1.3众数**

# %% [markdown]
# 方法一：使用numpy

# %%
# 在numpy中没有直接的⽅法，但是也可以这样实现：
# ⾸先⽣成随机数据
import random
data = [random.choice(range(1,5)) for i in range(100)]
print(data)
# Out:
# [2, 2, 4, 3, 4, 1, 1, 4, 2, 1, 2, 2, 2, 3, 3, 1, 4, 3, 4, 1, 3, 2, 2, 1, 2, 4, 2, 4, 3, 4, 4, 2, 3, 3, 3, 2, 4, 3, 2, 3, 4, 4, 4, 4, 1, 1, 1, 2, 4, 1, 4, 1, 3, 1, 3, 4, 1, 3, 4, 3, 4, 2, 4, 1, 3, 4, 3, 2, 4, 3, 2, 1, 4, 3, 4, 4, 2, 4, 2, 4, 3, 2, 3, 3, 3, 2, 1, 2, 4, 1, 3, 2, 3, 3, 4, 1, 1, 1, 4, 2]

# %%
counts = np.bincount(data)
print(counts)
np.argmax(counts)
# Out:
# [ 0 20 24 26 30]
# 4

# %% [markdown]
# 方法二：直接使用scipy下stats模块

# %%
from scipy import stats
stats.mode(data)
# Out:
# ModeResult(mode=array([4]), count=array([30]))

# %%
stats.mode(data)[0][0]
# Out:
# 4

# %% [markdown]
# # **2. 数据的基本统计描述-离散趋势**

# %%
import numpy as np
from sklearn.datasets import load_iris

# %%
iris_data = load_iris()
feature_1 = iris_data.data[:,0]
print(feature_1)
# Out:
# [5.1 4.9 4.7 4.6 5.  5.4 4.6 5.  4.4 4.9 5.4 4.8 4.8 4.3 5.8 5.7 5.4 5.1
#  5.7 5.1 5.4 5.1 4.6 5.1 4.8 5.  5.  5.2 5.2 4.7 4.8 5.4 5.2 5.5 4.9 5.
#  5.5 4.9 4.4 5.1 5.  4.5 4.4 5.  5.1 4.8 5.1 4.6 5.3 5.  7.  6.4 6.9 5.5
#  6.5 5.7 6.3 4.9 6.6 5.2 5.  5.9 6.  6.1 5.6 6.7 5.6 5.8 6.2 5.6 5.9 6.1
#  6.3 6.1 6.4 6.6 6.8 6.7 6.  5.7 5.5 5.5 5.8 6.  5.4 6.  6.7 6.3 5.6 5.5
#  5.5 6.1 5.8 5.  5.6 5.7 5.7 6.2 5.1 5.7 6.3 5.8 7.1 6.3 6.5 7.6 4.9 7.3
#  6.7 7.2 6.5 6.4 6.8 5.7 5.8 6.4 6.5 7.7 7.7 6.  6.9 5.6 7.7 6.3 6.7 7.2
#  6.2 6.1 6.4 7.2 7.4 7.9 6.4 6.3 6.1 7.7 6.3 6.4 6.  6.9 6.7 6.9 5.8 6.8
#  6.7 6.7 6.3 6.5 6.2 5.9]

# %% [markdown]
# ## **2.1极差**

# %%
feature_1.max()-feature_1.min()
# Out:
# 3.6000000000000005

# %%
np.max(feature_1)-np.min(feature_1)
# Out:
# 3.6000000000000005

# %% [markdown]
# ## **2.2四分位数**
# 利用np.percentile()函数

# %%
Q3 = np.percentile(feature_1,0.75)
print(Q3)
# Out:
# 4.4

# %%
Q1 = np.percentile(feature_1,0.25)
print(Q1)
# Out:
# 4.33725

# %%
IQR = Q3 - Q1
print(IQR)       #四分位数极差（四分位距）
# Out:
# 0.0627500000000003

# %% [markdown]
# ## **2.4五数概括**

# %%
#[最小值，第一四分位数，中位数，第三四分位数，最大值]
max_value = np.max(feature_1)
Q3 = np.percentile(feature_1,0.75)
median_value = np.median(feature_1)
Q1 = np.percentile(feature_1,0.25)
min_value = np.min(feature_1)
[min_value, Q1, median_value, Q3, max_value]
# Out:
# [4.3, 4.33725, 5.8, 4.4, 7.9]

# %% [markdown]
# ## **2.5 箱线图**
# #### **2.5.1 单⼀箱线图**

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.boxplot(x=feature_1)
plt.ylabel('values of ' + iris_data.feature_names[0])
plt.xlabel(iris_data.feature_names[0])
plt.show()

# %% [markdown]
# #### **2.5.2 多个箱线图**

# %%
from pandas import DataFrame
iris_df = DataFrame(iris_data.data, columns=iris_data.feature_names)

# %%
# %matplotlib inline
fig, axes = plt.subplots(1,4)
iris_df.plot(kind='box', ax=axes, subplots=True, title='All feature boxplots')
axes[0].set_ylabel(iris_df.columns[0])
axes[1].set_ylabel(iris_df.columns[1])
axes[2].set_ylabel(iris_df.columns[2])
axes[3].set_ylabel(iris_df.columns[3])
fig.subplots_adjust(wspace=1, hspace=1)
fig.show()
# Out:
# c:\users\fangw\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:9: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   if __name__ == '__main__':

# %% [markdown]
# ## **2.6 ⽅差和标准差**

# %%
# ⽅差
var = np.var(feature_1)
var
# Out:
# 0.6811222222222223

# %%
# 所有维度⽅差
var_all = np.var(iris_data.data, axis=0)
var_all
# Out:
# array([0.68112222, 0.18871289, 3.09550267, 0.57713289])

# %%
# 标准差
std = np.std(feature_1)
std
# Out:
# 0.8253012917851409

# %%
# 所有维度标准差
std_all = np.std(iris_data.data, axis=0)
std_all
# Out:
# array([0.82530129, 0.43441097, 1.75940407, 0.75969263])

# %% [markdown]
# ## **2.7 DataFrame描述性统计**

# %%
iris_df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %% [markdown]
# # **3. 数据的基本统计描述-基本统计图**

# %%
import numpy as np
from sklearn.datasets import load_iris
iris_data = load_iris()
sample_1 = iris_data.data[0,:]

# %% [markdown]
# ## **3.1 条形图**

# %%
p1 = plt.bar(range(1, len(sample_1)+1),
height = sample_1,
tick_label = iris_data.feature_names,
width=0.3)
plt.ylabel('cm')
plt.title('bar of first data')
plt.show()

# %% [markdown]
# ## **3.2饼形图**

# %%
import matplotlib.pyplot as plt
labels = 'Sunny', 'Windy', 'Frogy', 'Snow'
sizes = [15, 30, 45, 10]
explode = (0, 0.1, 0, 0)             # 这⾥只弹出第⼆个天⽓(i.e. 'Hogs')
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
shadow=True, startangle=90)
ax1.axis('equal') # Equal aspect ratio ensures that pie is drawn as a cir
plt.show()

# %% [markdown]
# ## **3.3折线图**

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(0, 5, 0.1)
y = np.sin(x)
plt.plot(x, y)
plt.show()

# %% [markdown]
# ## **3.4直方图**

# %%
import numpy as np
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
iris_data = load_iris()
feature_2 = iris_data.data[:,1]

# %%
plt.hist(feature_2, bins=10)
plt.show()

# %% [markdown]
# ## **3.5散点图**

# %%
feature_1 = iris_data.data[:,0]
feature_3 = iris_data.data[:,2]
plt.scatter(feature_1,feature_3)
plt.show()

# %% [markdown]
# ## **3.6分数图-分位数图**

# %%
# 调⽤ scipy包中的scipy.stats.probplot函数
# 验证feature_3是否服从正态分布
from scipy import stats
import matplotlib.pyplot as plt

# %%
res = stats.probplot(feature_3, plot=plt)

# %% [markdown]
# # **4.数据的基本统计描述——高级绘图**
# ## **4.1雷达图**

# %%
# 学⽣成绩雷达图
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
plt.rcParams['font.sans-serif'] = ['simhei']
# 准备数据和参数
labels=np.array(['语⽂','数学','英语','物理','化学','⽣物'])
n_attr=len(labels)
scores = np.array([88.7,85,90,95,70,96])
angles = np.linspace(0, 2*np.pi, n_attr, endpoint=False)
scores = np.concatenate((scores, [scores[0]])) # 闭合
angles = np.concatenate((angles, [angles[0]])) # 闭合
scores
# Out:
# array([88.7, 85. , 90. , 95. , 70. , 96. , 88.7])

# %%
# 绘图
fig = plt.figure(facecolor="white")
plt.subplot(111,polar=True)
plt.plot(angles, scores, 'bo-', color = 'g',linewidth = 2)
plt.fill(angles, scores, facecolor = 'g',alpha = 0.2)
plt.thetagrids(angles*180/np.pi,labels)
plt.title('成绩雷达图', ha='center')
plt.grid(True)
plt.show()
# Out:
# C:\Users\fangw\AppData\Roaming\Python\Python37\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 12098 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\fangw\AppData\Roaming\Python\Python37\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 12131 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\fangw\AppData\Roaming\Python\Python37\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 12098 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\fangw\AppData\Roaming\Python\Python37\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 12131 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ## **4.2词云**
# ### **4.2.1安装包**

# %% [markdown]
# **命令**
# pip install wordcloud
# pip install jieba
# ### **4.2.2. 绘制词云**
# 使⽤数据为2019年政府⼯作报告全⽂
# ⽂件："政府⼯作报告2019.txt"
# 原⽂地址：
# http://www.gov.cn/zhuanti/2019qglh/2019lhzfgzbg/index.htm
# (http://www.gov.cn/zhuanti/2019qglh/2019lhzfgzbg/index.htm)

# %%
# 《政府⼯作报告2019》
import jieba
from wordcloud import WordCloud
import PIL
import os
def chinese_jieba(txt):
    wordlist_jieba = jieba.cut(txt) # 将⽂本分割，返回列表
    txt_jieba = " ".join(wordlist_jieba) # 将列表拼接为以空格为间断的字符串
    return txt_jieba

# %%
stopwords = {'这些':0, '那些':0, '因为':0, '所以':0}
alice_mask = np.array(PIL.Image.open('china.jpg'))
with open('政府⼯作报告_2019.txt', encoding='utf8') as fp:
    txt = fp.read()
    cutted_text = chinese_jieba(txt)
    # print(txt)
    wordcloud = WordCloud(font_path = r'C:\Windows\Fonts\STKAITI.TTF', # 字体
    background_color = 'white', # 背景⾊
    max_words = 80, # 最⼤显示单词数
    max_font_size = 80, # 频率最⼤单词字体⼤⼩
    mask = alice_mask,
    stopwords = stopwords # 过滤停⽤词
    ).generate(cutted_text)
    image = wordcloud.to_image()
    image.show()

# %% [markdown]
# ![image.png](attachment:image.png)
